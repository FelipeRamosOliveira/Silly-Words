# %%
if 'init_executed' not in globals():
    # %run __init__.py
    init_executed = True

# %%
import pandas as pd
from sillywords.text import NgramsCount
from sillywords.charts import WordDistPlot

df = pd.read_csv("data/test_corpus.csv")
df.head()
# Out:
#                                                 text  label
# 0  @__andrea__b \nO cara vive em outro mundo\nNão...      1
# 1  @_carmeloneto Estes incompetentes não cuidam n...      0
# 2  @_carmeloneto \nOs 'cumpanhero' quebraram toda...      0
# 3  @_GlitteryKisses é isso não conseguem pensar n...      0
# 4                @_iglira bom dia macaco branco haha      1

# %%
WordCount = NgramsCount(df,nintens=1,rank=50)
WordCount.head(10)
# Out:
#     Word  Frequency
# 0     de       2457
# 1     co       2421
# 2  https       2338
# 3    que       2141
# 4    não       1644
# 5     rt       1131
# 6     do       1006
# 7     da        892
# 8     se        804
# 9    com        717

# %%
ax_WordDistPlot = WordDistPlot(WordCount,x='Word',y='Frequency',rank=25)
